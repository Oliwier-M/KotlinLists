# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df = pd.read_csv('electricity.csv',index_col='Month',parse_dates=True)
df
# Out:
# C:\Users\omord\AppData\Local\Temp\ipykernel_18024\2366828151.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('electricity.csv',index_col='Month',parse_dates=True)
#                    Sales
# Month
# 2023-12-01           NaN
# 2023-11-01  310959.15193
# 2023-10-01  293487.06424
# 2023-10-01           NaN
# 2023-10-01           NaN
# ...                  ...
# 2001-03-01           NaN
# 2001-03-01           NaN
# 2001-02-01  269298.40142
# 2001-01-01  272334.73804
# 2000-12-01  310816.06880
#
# [505 rows x 1 columns]

# %%
df['diff1'] = df['Sales'].diff()
df
# Out:
#                    Sales        diff1
# Month
# 2023-12-01           NaN          NaN
# 2023-11-01  310959.15193          NaN
# 2023-10-01  293487.06424 -17472.08769
# 2023-10-01           NaN          NaN
# 2023-10-01           NaN          NaN
# ...                  ...          ...
# 2001-03-01           NaN          NaN
# 2001-03-01           NaN          NaN
# 2001-02-01  269298.40142          NaN
# 2001-01-01  272334.73804   3036.33662
# 2000-12-01  310816.06880  38481.33076
#
# [505 rows x 2 columns]

# %%
df['diff1'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
fig1 = plot_acf(df['diff1'].dropna(), lags=100)
